# %%
# Imports.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load data.
sellData = pd.read_csv('Properati-Data.csv')

# %%
# Take a quick look.
sellData.head()
# Out:
#                                          id  created_on operation  \
# 0  c8a66ee9e3da083ab66dacd165e8a5cc718b1cf2  2012-09-19      sell
# 1  a205c53378e7879cf7519659317fb410c060d20e  2012-10-22      sell
# 2  e06d6f864a0b91346594da4d27ceddcef0947ea6  2012-11-01      sell
# 3  a07927207d2a03de5f4ba7fd76f670d6285a3315  2012-11-26      sell
# 4  9446052c949050359fb08b9f1ba83ba2eaa20c99  2012-12-08      sell
#
#   property_type            place_name  \
# 0         house  San Antonio De Padua
# 1         house  San Antonio De Padua
# 2     apartment         Mar del Plata
# 3         house  Sierra de los Padres
# 4         house             Mataderos
#
#                              place_with_parent_names country_name  \
# 0  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
# 1  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
# 2  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# ...

# %%
sellData.tail()
# Out:
#                                               id  created_on operation  \
# 187477  91b7a3a73c3d869babaf11a446fad1fd967bc35d  2017-08-01      sell
# 187478  aba0d7d6f6f87365d97a4f7bc133f3ef59a70a20  2017-08-01      sell
# 187479  e935e6dca58a5b2fec2101f8c7ac1494722119a6  2017-08-01      sell
# 187480  d236e3424ac94ab9fcd5d2c22aed59eeed695adc  2017-08-01      sell
# 187481  9439664d30d10181efbae84ed01e6d991087deed  2017-08-01      sell
#
#        property_type               place_name  \
# 187477         house                  Rosario
# 187478         house                 Belgrano
# 187479         house                 Martínez
# 187480     apartment               Villa Luro
# 187481         house  San Carlos de Bariloche
#
#                                   place_with_parent_names country_name  \
# 187477                       |Argentina|Santa Fe|Rosario|    Argentina
# 187478               |Argentina|Capital Federal|Belgrano|    Argentina
# ...

# %%
# Information about the dataset
sellData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187482 entries, 0 to 187481
# Data columns (total 27 columns):
# id                            187482 non-null object
# created_on                    187482 non-null object
# operation                     187482 non-null object
# property_type                 187482 non-null object
# place_name                    187447 non-null object
# place_with_parent_names       187482 non-null object
# country_name                  187482 non-null object
# state_name                    187482 non-null object
# geonames_id                   158318 non-null float64
# lat-lon                       118761 non-null object
# lat                           118761 non-null float64
# lon                           118761 non-null float64
# price                         154443 non-null float64
# currency                      154441 non-null object
# price_aprox_local_currency    154443 non-null float64
# ...

# %%
# Info about the columns of the dataset.
sellData.columns
# Out:
# Index([u'id', u'created_on', u'operation', u'property_type', u'place_name',
#        u'place_with_parent_names', u'country_name', u'state_name',
#        u'geonames_id', u'lat-lon', u'lat', u'lon', u'price', u'currency',
#        u'price_aprox_local_currency', u'price_aprox_usd',
#        u'surface_total_in_m2', u'surface_covered_in_m2', u'price_usd_per_m2',
#        u'price_per_m2', u'floor', u'rooms', u'expenses', u'properati_url',
#        u'description', u'title', u'image_thumbnail'],
#       dtype='object')

# %%
# Info about numerics attributes of the dataset.
sellData.describe()
# Out:
#         geonames_id            lat            lon         price  \
# count  1.583180e+05  118761.000000  118761.000000  1.544430e+05
# mean   3.560821e+06     -34.775631     -59.207578  4.402848e+05
# std    3.442029e+05       2.071562       2.293300  1.915257e+06
# min    3.427208e+06     -54.833014     -75.678931  0.000000e+00
# 25%    3.430116e+06     -34.729040     -58.718531  1.050000e+05
# 50%    3.433359e+06     -34.604154     -58.483665  1.800000e+05
# 75%    3.832260e+06     -34.457223     -58.383317  3.950000e+05
# max    6.948895e+06       4.545843     -40.149218  6.500000e+08
#
#        price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# count                1.544430e+05     1.544430e+05        125027.000000
# mean                 4.298946e+06     2.436423e+05           297.023707
# std                  6.870371e+06     3.893775e+05          2072.795972
# min                  0.000000e+00     0.000000e+00             0.000000
# ...
